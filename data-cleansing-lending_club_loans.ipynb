# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Description

# %%
desc_df = pd.read_csv('dataset/LCDataDictionary.csv')

# %%
pd.set_option("display.max_colwidth",-1)

# %%
desc_df[:60]
# Out:
#                        LoanStatNew  \
# 0   acc_now_delinq
# 1   acc_open_past_24mths
# 2   addr_state
# 3   all_util
# 4   annual_inc
# 5   annual_inc_joint
# 6   application_type
# 7   avg_cur_bal
# 8   bc_open_to_buy
# 9   bc_util
# 10  chargeoff_within_12_mths
# 11  collection_recovery_fee
# 12  collections_12_mths_ex_med
# 13  delinq_2yrs
# 14  delinq_amnt
# 15  desc
# 16  dti
# 17  dti_joint
# 18  earliest_cr_line
# 19  emp_length
# 20  emp_title
# 21  fico_range_high
# 22  fico_range_low
# 23  funded_amnt
# 24  funded_amnt_inv
# 25  grade
# 26  home_ownership
# 27  id
# 28  il_util
# 29  initial_list_status
# 30  inq_fi
# 31  inq_last_12m
# 32  inq_last_6mths
# 33  installment
# 34  int_rate
# 35  issue_d
# 36  last_credit_pull_d
# 37  last_fico_range_high
# 38  last_fico_range_low
# 39  last_pymnt_amnt
# 40  last_pymnt_d
# 41  loan_amnt
# 42  loan_status
# 43  max_bal_bc
# 44  member_id
# 45  mo_sin_old_il_acct
# 46  mo_sin_old_rev_tl_op
# 47  mo_sin_rcnt_rev_tl_op
# 48  mo_sin_rcnt_tl
# 49  mort_acc
# 50  mths_since_last_delinq
# 51  mths_since_last_major_derog
# 52  mths_since_last_record
# 53  mths_since_rcnt_il
# 54  mths_since_recent_bc
# 55  mths_since_recent_bc_dlq
# 56  mths_since_recent_inq
# 57  mths_since_recent_revol_delinq
# 58  next_pymnt_d
# 59  num_accts_ever_120_pd
#
#                                                                                                                                                                                                            Description
# 0   The number of accounts on which the borrower is now delinquent.
# 1   Number of trades opened in past 24 months.
# 2   The state provided by the borrower in the loan application
# 3   Balance to credit limit on all trades
# 4   The self-reported annual income provided by the borrower during registration.
# 5   The combined self-reported annual income provided by the co-borrowers during registration
# 6   Indicates whether the loan is an individual application or a joint application with two co-borrowers
# 7   Average current balance of all accounts
# 8   Total open to buy on revolving bankcards.
# 9   Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# 10  Number of charge-offs within 12 months
# 11  post charge off collection fee
# 12  Number of collections in 12 months excluding medical collections
# 13  The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# 14  The past-due amount owed for the accounts on which the borrower is now delinquent.
# 15  Loan description provided by the borrower
# 16  A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# 17  A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# 18  The month the borrower's earliest reported credit line was opened
# 19  Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# 20  The job title supplied by the Borrower when applying for the loan.*
# 21  The upper boundary range the borrower’s FICO at loan origination belongs to.
# 22  The lower boundary range the borrower’s FICO at loan origination belongs to.
# 23  The total amount committed to that loan at that point in time.
# 24  The total amount committed by investors for that loan at that point in time.
# 25  LC assigned loan grade
# 26  The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.
# 27  A unique LC assigned ID for the loan listing.
# 28  Ratio of total current balance to high credit/credit limit on all install acct
# 29  The initial listing status of the loan. Possible values are – W, F
# 30  Number of personal finance inquiries
# 31  Number of credit inquiries in past 12 months
# 32  The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# 33  The monthly payment owed by the borrower if the loan originates.
# 34  Interest Rate on the loan
# 35  The month which the loan was funded
# 36  The most recent month LC pulled credit for this loan
# 37  The upper boundary range the borrower’s last FICO pulled belongs to.
# 38  The lower boundary range the borrower’s last FICO pulled belongs to.
# 39  Last total payment amount received
# 40  Last month payment was received
# 41  The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# 42  Current status of the loan
# 43  Maximum current balance owed on all revolving accounts
# 44  A unique LC assigned Id for the borrower member.
# 45  Months since oldest bank installment account opened
# 46  Months since oldest revolving account opened
# 47  Months since most recent revolving account opened
# 48  Months since most recent account opened
# 49  Number of mortgage accounts.
# 50  The number of months since the borrower's last delinquency.
# 51  Months since most recent 90-day or worse rating
# 52  The number of months since the last public record.
# 53  Months since most recent installment accounts opened
# 54  Months since most recent bankcard account opened.
# 55  Months since most recent bankcard delinquency
# 56  Months since most recent inquiry.
# 57  Months since most recent revolving delinquency.
# 58  Next scheduled payment date
# 59  Number of accounts ever 120 or more days past due

# %%
desc_df[60:]
# Out:
#                     LoanStatNew  \
# 60   num_actv_bc_tl
# 61   num_actv_rev_tl
# 62   num_bc_sats
# 63   num_bc_tl
# 64   num_il_tl
# 65   num_op_rev_tl
# 66   num_rev_accts
# 67   num_rev_tl_bal_gt_0
# 68   num_sats
# 69   num_tl_120dpd_2m
# 70   num_tl_30dpd
# 71   num_tl_90g_dpd_24m
# 72   num_tl_op_past_12m
# 73   open_acc
# 74   open_acc_6m
# 75   open_il_12m
# 76   open_il_24m
# 77   open_il_6m
# 78   open_rv_12m
# 79   open_rv_24m
# 80   out_prncp
# 81   out_prncp_inv
# 82   pct_tl_nvr_dlq
# 83   percent_bc_gt_75
# 84   policy_code
# 85   pub_rec
# 86   pub_rec_bankruptcies
# 87   purpose
# 88   pymnt_plan
# 89   recoveries
# 90   revol_bal
# 91   revol_util
# 92   sub_grade
# 93   tax_liens
# 94   term
# 95   title
# 96   tot_coll_amt
# 97   tot_cur_bal
# 98   tot_hi_cred_lim
# 99   total_acc
# 100  total_bal_ex_mort
# 101  total_bal_il
# 102  total_bc_limit
# 103  total_cu_tl
# 104  total_il_high_credit_limit
# 105  total_pymnt
# 106  total_pymnt_inv
# 107  total_rec_int
# 108  total_rec_late_fee
# 109  total_rec_prncp
# 110  total_rev_hi_lim
# 111  url
# 112  verification_status
# 113  verified_status_joint
# 114  zip_code
# 115  NaN
# 116  NaN
#
#                                                                                                                     Description
# 60   Number of currently active bankcard accounts
# 61   Number of currently active revolving trades
# 62   Number of satisfactory bankcard accounts
# 63   Number of bankcard accounts
# 64   Number of installment accounts
# 65   Number of open revolving accounts
# 66   Number of revolving accounts
# 67   Number of revolving trades with balance >0
# 68   Number of satisfactory accounts
# 69   Number of accounts currently 120 days past due (updated in past 2 months)
# 70   Number of accounts currently 30 days past due (updated in past 2 months)
# 71   Number of accounts 90 or more days past due in last 24 months
# 72   Number of accounts opened in past 12 months
# 73   The number of open credit lines in the borrower's credit file.
# 74   Number of open trades in last 6 months
# 75   Number of installment accounts opened in past 12 months
# 76   Number of installment accounts opened in past 24 months
# 77   Number of currently active installment trades
# 78   Number of revolving trades opened in past 12 months
# 79   Number of revolving trades opened in past 24 months
# 80   Remaining outstanding principal for total amount funded
# 81   Remaining outstanding principal for portion of total amount funded by investors
# 82   Percent of trades never delinquent
# 83   Percentage of all bankcard accounts > 75% of limit.
# 84   publicly available policy_code=1\nnew products not publicly available policy_code=2
# 85   Number of derogatory public records
# 86   Number of public record bankruptcies
# 87   A category provided by the borrower for the loan request.
# 88   Indicates if a payment plan has been put in place for the loan
# 89   post charge off gross recovery
# 90   Total credit revolving balance
# 91   Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# 92   LC assigned loan subgrade
# 93   Number of tax liens
# 94   The number of payments on the loan. Values are in months and can be either 36 or 60.
# 95   The loan title provided by the borrower
# 96   Total collection amounts ever owed
# 97   Total current balance of all accounts
# 98   Total high credit/credit limit
# 99   The total number of credit lines currently in the borrower's credit file
# 100  Total credit balance excluding mortgage
# 101  Total current balance of all installment accounts
# 102  Total bankcard high credit/credit limit
# 103  Number of finance trades
# 104  Total installment high credit/credit limit
# 105  Payments received to date for total amount funded
# 106  Payments received to date for portion of total amount funded by investors
# 107  Interest received to date
# 108  Late fees received to date
# 109  Principal received to date
# 110  Total revolving high credit/credit limit
# 111  URL for the LC page with listing data.
# 112  Indicates if income was verified by LC, not verified, or if the income source was verified
# 113  Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
# 114  The first 3 numbers of the zip code provided by the borrower in the loan application.
# 115  NaN
# 116  * Employer Title replaces Employer Name for all loans listed after 9/23/2013

# %% [markdown]
# ### Loading Dataset

# %%
loan_df = pd.read_csv('dataset/lending_club_loans.csv', skiprows=1, low_memory=False)

# %%
loan_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0  5000.0     5000.0       4975.0            36 months
# 1  1077430  1314167.0  2500.0     2500.0       2500.0            60 months
# 2  1077175  1313524.0  2400.0     2400.0       2400.0            36 months
# 3  1076863  1277178.0  10000.0    10000.0      10000.0           36 months
# 4  1075358  1311748.0  3000.0     3000.0       3000.0            60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%  162.87       B     B2        ... NaN
# 1   15.27%  59.83        C     C4        ... NaN
# 2   15.96%  84.33        C     C5        ... NaN
# 3   13.49%  339.31       C     C1        ... NaN
# 4   12.69%  67.79        B     B5        ... NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0 NaN                NaN            NaN                0.0
# 1 NaN                NaN            NaN                0.0
# 2 NaN                NaN            NaN                0.0
# 3 NaN                NaN            NaN                0.0
# 4 NaN                NaN            NaN                0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0  0.0      NaN             NaN               NaN
# 1  0.0      NaN             NaN               NaN
# 2  0.0      NaN             NaN               NaN
# 3  0.0      NaN             NaN               NaN
# 4  0.0      NaN             NaN               NaN
#
#   total_il_high_credit_limit
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 115 columns]

# %%
loan_df.shape
# Out:
# (42538, 115)

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ### Missing Values

# %%
clean_df = loan_df.copy()

# %%
clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0  5000.0     5000.0       4975.0            36 months
# 1  1077430  1314167.0  2500.0     2500.0       2500.0            60 months
# 2  1077175  1313524.0  2400.0     2400.0       2400.0            36 months
# 3  1076863  1277178.0  10000.0    10000.0      10000.0           36 months
# 4  1075358  1311748.0  3000.0     3000.0       3000.0            60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%  162.87       B     B2        ... NaN
# 1   15.27%  59.83        C     C4        ... NaN
# 2   15.96%  84.33        C     C5        ... NaN
# 3   13.49%  339.31       C     C1        ... NaN
# 4   12.69%  67.79        B     B5        ... NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0 NaN                NaN            NaN                0.0
# 1 NaN                NaN            NaN                0.0
# 2 NaN                NaN            NaN                0.0
# 3 NaN                NaN            NaN                0.0
# 4 NaN                NaN            NaN                0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0  0.0      NaN             NaN               NaN
# 1  0.0      NaN             NaN               NaN
# 2  0.0      NaN             NaN               NaN
# 3  0.0      NaN             NaN               NaN
# 4  0.0      NaN             NaN               NaN
#
#   total_il_high_credit_limit
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 115 columns]

# %%
# checking total null values in each columns

for cols in clean_df:
    print(clean_df[cols].isna().sum())
# Out:
# 0
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 2629
# 1115
# 3
# 7
# 3
# 3
# 3
# 3
# 3
# 13296
# 3
# 16
# 3
# 3
# 3
# 32
# 32
# 3
# 3
# 32
# 26929
# 38887
# 32
# 32
# 3
# 93
# 32
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 86
# 3
# 39242
# 7
# 3
# 3
# 148
# 42538
# 3
# 3
# 42538
# 42538
# 42538
# 32
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 148
# 32
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 42538
# 1368
# 108
# 42538
# 42538
# 42538
# 42538

# %%
# columns, where null values are more than 38000

null_cols = []
for cols in clean_df:
    if clean_df[cols].isna().sum() > 38000:
        null_cols.append(cols)

# %%
len(null_cols)
# Out:
# 56

# %%
clean_df[null_cols]
# Out:
#        mths_since_last_record next_pymnt_d  mths_since_last_major_derog  \
# 0     NaN                      NaN         NaN
# 1     NaN                      NaN         NaN
# 2     NaN                      NaN         NaN
# 3     NaN                      NaN         NaN
# 4     NaN                      Oct-2016    NaN
# ...    ..                           ...     ..
# 42533 NaN                      Jul-2010    NaN
# 42534 NaN                      Jul-2010    NaN
# 42535 NaN                      Jul-2010    NaN
# 42536 NaN                      NaN         NaN
# 42537 NaN                      NaN         NaN
#
#        annual_inc_joint  dti_joint  verification_status_joint  tot_coll_amt  \
# 0     NaN               NaN        NaN                        NaN
# 1     NaN               NaN        NaN                        NaN
# 2     NaN               NaN        NaN                        NaN
# 3     NaN               NaN        NaN                        NaN
# 4     NaN               NaN        NaN                        NaN
# ...    ..                ..         ..                         ..
# 42533 NaN               NaN        NaN                        NaN
# 42534 NaN               NaN        NaN                        NaN
# 42535 NaN               NaN        NaN                        NaN
# 42536 NaN               NaN        NaN                        NaN
# 42537 NaN               NaN        NaN                        NaN
#
#        tot_cur_bal  open_acc_6m  open_il_6m  ...  num_tl_120dpd_2m  \
# 0     NaN          NaN          NaN          ... NaN
# 1     NaN          NaN          NaN          ... NaN
# 2     NaN          NaN          NaN          ... NaN
# 3     NaN          NaN          NaN          ... NaN
# 4     NaN          NaN          NaN          ... NaN
# ...    ..           ..           ..          ...  ..
# 42533 NaN          NaN          NaN          ... NaN
# 42534 NaN          NaN          NaN          ... NaN
# 42535 NaN          NaN          NaN          ... NaN
# 42536 NaN          NaN          NaN          ... NaN
# 42537 NaN          NaN          NaN          ... NaN
#
#        num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0     NaN           NaN                 NaN                 NaN
# 1     NaN           NaN                 NaN                 NaN
# 2     NaN           NaN                 NaN                 NaN
# 3     NaN           NaN                 NaN                 NaN
# 4     NaN           NaN                 NaN                 NaN
# ...    ..            ..                  ..                  ..
# 42533 NaN           NaN                 NaN                 NaN
# 42534 NaN           NaN                 NaN                 NaN
# 42535 NaN           NaN                 NaN                 NaN
# 42536 NaN           NaN                 NaN                 NaN
# 42537 NaN           NaN                 NaN                 NaN
#
#        percent_bc_gt_75  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0     NaN               NaN              NaN                NaN
# 1     NaN               NaN              NaN                NaN
# 2     NaN               NaN              NaN                NaN
# 3     NaN               NaN              NaN                NaN
# 4     NaN               NaN              NaN                NaN
# ...    ..                ..               ..                 ..
# 42533 NaN               NaN              NaN                NaN
# 42534 NaN               NaN              NaN                NaN
# 42535 NaN               NaN              NaN                NaN
# 42536 NaN               NaN              NaN                NaN
# 42537 NaN               NaN              NaN                NaN
#
#        total_il_high_credit_limit
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...    ..
# 42533 NaN
# 42534 NaN
# 42535 NaN
# 42536 NaN
# 42537 NaN
#
# [42538 rows x 56 columns]

# %%
clean_df.drop(columns=null_cols, axis=1, inplace=True)

# %%
clean_df.shape
# Out:
# (42538, 59)

# %%
clean_df.isna().sum()
# Out:
# id                            0
# member_id                     3
# loan_amnt                     3
# funded_amnt                   3
# funded_amnt_inv               3
# term                          3
# int_rate                      3
# installment                   3
# grade                         3
# sub_grade                     3
# emp_title                     2629
# emp_length                    1115
# home_ownership                3
# annual_inc                    7
# verification_status           3
# issue_d                       3
# loan_status                   3
# pymnt_plan                    3
# url                           3
# desc                          13296
# purpose                       3
# title                         16
# zip_code                      3
# addr_state                    3
# dti                           3
# delinq_2yrs                   32
# earliest_cr_line              32
# fico_range_low                3
# fico_range_high               3
# inq_last_6mths                32
# mths_since_last_delinq        26929
# open_acc                      32
# pub_rec                       32
# revol_bal                     3
# revol_util                    93
# total_acc                     32
# initial_list_status           3
# out_prncp                     3
# out_prncp_inv                 3
# total_pymnt                   3
# total_pymnt_inv               3
# total_rec_prncp               3
# total_rec_int                 3
# total_rec_late_fee            3
# recoveries                    3
# collection_recovery_fee       3
# last_pymnt_d                  86
# last_pymnt_amnt               3
# last_credit_pull_d            7
# last_fico_range_high          3
# last_fico_range_low           3
# collections_12_mths_ex_med    148
# policy_code                   3
# application_type              3
# acc_now_delinq                32
# chargeoff_within_12_mths      148
# delinq_amnt                   32
# pub_rec_bankruptcies          1368
# tax_liens                     108
# dtype: int64

# %%
clean_df['emp_title'].value_counts()
# Out:
# US Army                  139
# Bank of America          115
# IBM                      72
# AT&T                     61
# Kaiser Permanente        61
#                          ..
# Fleetwood Goldcowyard    1
# Palco Sports             1
# citibank  n.a.           1
# Arrowhead Dermatology    1
# Chandler School          1
# Name: emp_title, Length: 30658, dtype: int64

# %%
clean_df['emp_title'].isna().sum()
# Out:
# 2629

# %%
clean_df['emp_title'].fillna('Other', inplace=True)

# %%
clean_df['emp_title'].value_counts()
# Out:
# Other                    2630
# US Army                  139
# Bank of America          115
# IBM                      72
# AT&T                     61
#                          ..
# Palco Sports             1
# citibank  n.a.           1
# Arrowhead Dermatology    1
# NCM Media Networks       1
# Chandler School          1
# Name: emp_title, Length: 30658, dtype: int64

# %%
clean_df['emp_length'].value_counts()
# Out:
# 10+ years    9369
# < 1 year     5062
# 2 years      4743
# 3 years      4364
# 4 years      3649
# 1 year       3595
# 5 years      3458
# 6 years      2375
# 7 years      1875
# 8 years      1592
# 9 years      1341
# Name: emp_length, dtype: int64

# %%
clean_df['emp_length'].isna().sum()
# Out:
# 1115

# %%
clean_df['emp_length'].fillna('< 1 year', inplace=True)

# %%
clean_df['emp_length'].value_counts()
# Out:
# 10+ years    9369
# < 1 year     6177
# 2 years      4743
# 3 years      4364
# 4 years      3649
# 1 year       3595
# 5 years      3458
# 6 years      2375
# 7 years      1875
# 8 years      1592
# 9 years      1341
# Name: emp_length, dtype: int64

# %%
clean_df['desc']
# Out:
# 0          Borrower added on 12/22/11 > I need to upgrade my business technologies.<br>
# 1          Borrower added on 12/22/11 > I plan to use this money to finance the motorcycle i am looking at. I plan to have it paid off as soon as possible/when i sell my old bike. I only need this money because the deal im looking at is to good to pass up.<br><br>  Borrower added on 12/22/11 > I plan to use this money to finance the motorcycle i am looking at. I plan to have it paid off as soon as possible/when i sell my old bike.I only need this money because the deal im looking at is to good to pass up. I have finished college with an associates degree in business and its takingmeplaces<br>
# 2        NaN
# 3          Borrower added on 12/21/11 > to pay for property tax (borrow from friend, need to pay back) & central A/C need to be replace. I'm very sorry to let my loan expired last time.<br>
# 4          Borrower added on 12/21/11 > I plan on combining three large interest bills together and freeing up some extra each month to pay toward other bills.  I've always been a good payor but have found myself needing to make adjustments to my budget due to a medical scare. My job is very stable, I love it.<br>
#                                                                                                                                                                 ...
# 42533    I need to pay $2,100 for fixing my Volvo :)  Any help appreciated!
# 42534    Hi,   I'm buying  a used car. Anybody on facebook wants to finance me?   Thanks
# 42535    I need to make several improvements around the house - fix garage, fix back fencing, and misc other.
# 42536    NaN
# 42537    NaN
# Name: desc, Length: 42538, dtype: object

# %%
clean_df['desc'].isna().sum()
# Out:
# 13296

# %%
clean_df['mths_since_last_delinq'].isna().sum()
# Out:
# 26929

# %%
clean_df['mths_since_last_delinq'].isna().sum()/clean_df.shape[0]
# Out:
# 0.6330575015280455

# %%
clean_df.drop(columns=['desc','url','mths_since_last_delinq'], axis=1, inplace=True)

# %%
clean_df.isna().sum()
# Out:
# id                            0
# member_id                     3
# loan_amnt                     3
# funded_amnt                   3
# funded_amnt_inv               3
# term                          3
# int_rate                      3
# installment                   3
# grade                         3
# sub_grade                     3
# emp_title                     0
# emp_length                    0
# home_ownership                3
# annual_inc                    7
# verification_status           3
# issue_d                       3
# loan_status                   3
# pymnt_plan                    3
# purpose                       3
# title                         16
# zip_code                      3
# addr_state                    3
# dti                           3
# delinq_2yrs                   32
# earliest_cr_line              32
# fico_range_low                3
# fico_range_high               3
# inq_last_6mths                32
# open_acc                      32
# pub_rec                       32
# revol_bal                     3
# revol_util                    93
# total_acc                     32
# initial_list_status           3
# out_prncp                     3
# out_prncp_inv                 3
# total_pymnt                   3
# total_pymnt_inv               3
# total_rec_prncp               3
# total_rec_int                 3
# total_rec_late_fee            3
# recoveries                    3
# collection_recovery_fee       3
# last_pymnt_d                  86
# last_pymnt_amnt               3
# last_credit_pull_d            7
# last_fico_range_high          3
# last_fico_range_low           3
# collections_12_mths_ex_med    148
# policy_code                   3
# application_type              3
# acc_now_delinq                32
# chargeoff_within_12_mths      148
# delinq_amnt                   32
# pub_rec_bankruptcies          1368
# tax_liens                     108
# dtype: int64

# %%
clean_df['pub_rec_bankruptcies'].value_counts()
# Out:
# 0.0    39316
# 1.0    1846
# 2.0    8
# Name: pub_rec_bankruptcies, dtype: int64

# %%
clean_df['pub_rec_bankruptcies'].fillna(0, inplace=True)

# %%
clean_df.isna().sum()
# Out:
# id                            0
# member_id                     3
# loan_amnt                     3
# funded_amnt                   3
# funded_amnt_inv               3
# term                          3
# int_rate                      3
# installment                   3
# grade                         3
# sub_grade                     3
# emp_title                     0
# emp_length                    0
# home_ownership                3
# annual_inc                    7
# verification_status           3
# issue_d                       3
# loan_status                   3
# pymnt_plan                    3
# purpose                       3
# title                         16
# zip_code                      3
# addr_state                    3
# dti                           3
# delinq_2yrs                   32
# earliest_cr_line              32
# fico_range_low                3
# fico_range_high               3
# inq_last_6mths                32
# open_acc                      32
# pub_rec                       32
# revol_bal                     3
# revol_util                    93
# total_acc                     32
# initial_list_status           3
# out_prncp                     3
# out_prncp_inv                 3
# total_pymnt                   3
# total_pymnt_inv               3
# total_rec_prncp               3
# total_rec_int                 3
# total_rec_late_fee            3
# recoveries                    3
# collection_recovery_fee       3
# last_pymnt_d                  86
# last_pymnt_amnt               3
# last_credit_pull_d            7
# last_fico_range_high          3
# last_fico_range_low           3
# collections_12_mths_ex_med    148
# policy_code                   3
# application_type              3
# acc_now_delinq                32
# chargeoff_within_12_mths      148
# delinq_amnt                   32
# pub_rec_bankruptcies          0
# tax_liens                     108
# dtype: int64

# %%
clean_df['collections_12_mths_ex_med'].value_counts()
# Out:
# 0.0    42390
# Name: collections_12_mths_ex_med, dtype: int64

# %%
clean_df['chargeoff_within_12_mths'].value_counts()
# Out:
# 0.0    42390
# Name: chargeoff_within_12_mths, dtype: int64

# %%
clean_df['tax_liens'].value_counts()
# Out:
# 0.0    42429
# 1.0        1
# Name: tax_liens, dtype: int64

# %%
clean_df.drop(columns=['collections_12_mths_ex_med','chargeoff_within_12_mths','tax_liens'], axis=1, inplace=True)

# %%
clean_df.isna().sum()
# Out:
# id                         0
# member_id                  3
# loan_amnt                  3
# funded_amnt                3
# funded_amnt_inv            3
# term                       3
# int_rate                   3
# installment                3
# grade                      3
# sub_grade                  3
# emp_title                  0
# emp_length                 0
# home_ownership             3
# annual_inc                 7
# verification_status        3
# issue_d                    3
# loan_status                3
# pymnt_plan                 3
# purpose                    3
# title                      16
# zip_code                   3
# addr_state                 3
# dti                        3
# delinq_2yrs                32
# earliest_cr_line           32
# fico_range_low             3
# fico_range_high            3
# inq_last_6mths             32
# open_acc                   32
# pub_rec                    32
# revol_bal                  3
# revol_util                 93
# total_acc                  32
# initial_list_status        3
# out_prncp                  3
# out_prncp_inv              3
# total_pymnt                3
# total_pymnt_inv            3
# total_rec_prncp            3
# total_rec_int              3
# total_rec_late_fee         3
# recoveries                 3
# collection_recovery_fee    3
# last_pymnt_d               86
# last_pymnt_amnt            3
# last_credit_pull_d         7
# last_fico_range_high       3
# last_fico_range_low        3
# policy_code                3
# application_type           3
# acc_now_delinq             32
# delinq_amnt                32
# pub_rec_bankruptcies       0
# dtype: int64

# %%
clean_df['last_pymnt_d'].value_counts()
# Out:
# Mar-2013    1070
# Dec-2014    949
# May-2013    943
# Feb-2013    906
# Mar-2012    893
#            ...
# Jun-2008    20
# Mar-2008    18
# Jan-2008    11
# Feb-2008    8
# Dec-2007    2
# Name: last_pymnt_d, Length: 106, dtype: int64

# %%
clean_df.dropna(subset=['last_pymnt_d','last_credit_pull_d'], axis=0, inplace=True)

# %%
clean_df.shape
# Out:
# (42448, 53)

# %%
clean_df.isna().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 4
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# purpose                    0
# title                      13
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                28
# earliest_cr_line           28
# fico_range_low             0
# fico_range_high            0
# inq_last_6mths             28
# open_acc                   28
# pub_rec                    28
# revol_bal                  0
# revol_util                 85
# total_acc                  28
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_d               0
# last_pymnt_amnt            0
# last_credit_pull_d         0
# last_fico_range_high       0
# last_fico_range_low        0
# policy_code                0
# application_type           0
# acc_now_delinq             28
# delinq_amnt                28
# pub_rec_bankruptcies       0
# dtype: int64

# %%
clean_df['title'].value_counts()
# Out:
# Debt Consolidation                       2256
# Debt Consolidation Loan                  1756
# Personal Loan                            706
# Consolidation                            546
# debt consolidation                       532
#                                         ...
# Credit Card Refinance car/studentloan    1
# retired vet                              1
# Refinancing Win Win Lending Club Loan    1
# equine purchase                          1
# wek refinance                            1
# Name: title, Length: 21223, dtype: int64

# %%
clean_df['title'].fillna('Other', inplace=True)

# %%
clean_df.isna().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 4
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                28
# earliest_cr_line           28
# fico_range_low             0
# fico_range_high            0
# inq_last_6mths             28
# open_acc                   28
# pub_rec                    28
# revol_bal                  0
# revol_util                 85
# total_acc                  28
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_d               0
# last_pymnt_amnt            0
# last_credit_pull_d         0
# last_fico_range_high       0
# last_fico_range_low        0
# policy_code                0
# application_type           0
# acc_now_delinq             28
# delinq_amnt                28
# pub_rec_bankruptcies       0
# dtype: int64

# %%
clean_df['delinq_2yrs'].isna().sum()
# Out:
# 28

# %%
clean_df['delinq_2yrs'].value_counts()
# Out:
# 0.0     37697
# 1.0     3588
# 2.0     769
# 3.0     242
# 4.0     71
# 5.0     27
# 6.0     13
# 7.0     6
# 8.0     3
# 11.0    2
# 9.0     1
# 13.0    1
# Name: delinq_2yrs, dtype: int64

# %%
clean_df['delinq_2yrs'].fillna(0, inplace=True)

# %%
clean_df['earliest_cr_line']
# Out:
# 0        Jan-1985
# 1        Apr-1999
# 2        Nov-2001
# 3        Feb-1996
# 4        Jan-1996
#            ...
# 42531    NaN
# 42532    NaN
# 42533    NaN
# 42534    NaN
# 42535    NaN
# Name: earliest_cr_line, Length: 42448, dtype: object

# %%
clean_df.drop(columns=['earliest_cr_line'], axis=1, inplace=True)

# %%
clean_df['revol_util'].value_counts()
# Out:
# 0%        1068
# 40.7%     65
# 0.2%      63
# 63%       63
# 66.6%     62
#           ..
# 105.7%    1
# 37.63%    1
# 106.1%    1
# 58.77%    1
# 47.36%    1
# Name: revol_util, Length: 1119, dtype: int64

# %%
clean_df['revol_util'].fillna('0%', inplace=True)

# %%
clean_df.isna().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 4
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# fico_range_low             0
# fico_range_high            0
# inq_last_6mths             28
# open_acc                   28
# pub_rec                    28
# revol_bal                  0
# revol_util                 0
# total_acc                  28
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_d               0
# last_pymnt_amnt            0
# last_credit_pull_d         0
# last_fico_range_high       0
# last_fico_range_low        0
# policy_code                0
# application_type           0
# acc_now_delinq             28
# delinq_amnt                28
# pub_rec_bankruptcies       0
# dtype: int64

# %%
clean_df.dropna(axis=0, inplace=True)

# %%
clean_df.reset_index(drop=True, inplace=True)

# %%
clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0  5000.0     5000.0       4975.0            36 months
# 1  1077430  1314167.0  2500.0     2500.0       2500.0            60 months
# 2  1077175  1313524.0  2400.0     2400.0       2400.0            36 months
# 3  1076863  1277178.0  10000.0    10000.0      10000.0           36 months
# 4  1075358  1311748.0  3000.0     3000.0       3000.0            60 months
#
#   int_rate  installment grade sub_grade  ... last_pymnt_d last_pymnt_amnt  \
# 0   10.65%  162.87       B     B2        ...  Jan-2015     171.62
# 1   15.27%  59.83        C     C4        ...  Apr-2013     119.66
# 2   15.96%  84.33        C     C5        ...  Jun-2014     649.91
# 3   13.49%  339.31       C     C1        ...  Jan-2015     357.48
# 4   12.69%  67.79        B     B5        ...  Sep-2016     67.79
#
#   last_credit_pull_d  last_fico_range_high last_fico_range_low policy_code  \
# 0  Sep-2016           744.0                 740.0               1.0
# 1  Sep-2016           499.0                 0.0                 1.0
# 2  Sep-2016           719.0                 715.0               1.0
# 3  Apr-2016           604.0                 600.0               1.0
# 4  Sep-2016           694.0                 690.0               1.0
#
#   application_type acc_now_delinq delinq_amnt pub_rec_bankruptcies
# 0  INDIVIDUAL       0.0            0.0         0.0
# 1  INDIVIDUAL       0.0            0.0         0.0
# 2  INDIVIDUAL       0.0            0.0         0.0
# 3  INDIVIDUAL       0.0            0.0         0.0
# 4  INDIVIDUAL       0.0            0.0         0.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Data Cleaning

# %%
new_clean_df = clean_df.copy()

# %%
new_clean_df.shape
# Out:
# (42420, 52)

# %%
new_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42420 entries, 0 to 42419
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       42420 non-null  object
#  1   member_id                42420 non-null  float64
#  2   loan_amnt                42420 non-null  float64
#  3   funded_amnt              42420 non-null  float64
#  4   funded_amnt_inv          42420 non-null  float64
#  5   term                     42420 non-null  object
#  6   int_rate                 42420 non-null  object
#  7   installment              42420 non-null  float64
#  8   grade                    42420 non-null  object
#  9   sub_grade                42420 non-null  object
#  10  emp_title                42420 non-null  object
#  11  emp_length               42420 non-null  object
#  12  home_ownership           42420 non-null  object
#  13  annual_inc               42420 non-null  float64
#  14  verification_status      42420 non-null  object
#  15  issue_d                  42420 non-null  object
#  16  loan_status              42420 non-null  object
#  17  pymnt_plan               42420 non-null  object
#  18  purpose                  42420 non-null  object
#  19  title                    42420 non-null  object
#  20  zip_code                 42420 non-null  object
#  21  addr_state               42420 non-null  object
#  22  dti                      42420 non-null  float64
#  23  delinq_2yrs              42420 non-null  float64
#  24  fico_range_low           42420 non-null  float64
#  25  fico_range_high          42420 non-null  float64
#  26  inq_last_6mths           42420 non-null  float64
#  27  open_acc                 42420 non-null  float64
#  28  pub_rec                  42420 non-null  float64
#  29  revol_bal                42420 non-null  float64
#  30  revol_util               42420 non-null  object
#  31  total_acc                42420 non-null  float64
#  32  initial_list_status      42420 non-null  object
#  33  out_prncp                42420 non-null  float64
#  34  out_prncp_inv            42420 non-null  float64
#  35  total_pymnt              42420 non-null  float64
#  36  total_pymnt_inv          42420 non-null  float64
#  37  total_rec_prncp          42420 non-null  float64
#  38  total_rec_int            42420 non-null  float64
#  39  total_rec_late_fee       42420 non-null  float64
#  40  recoveries               42420 non-null  float64
#  41  collection_recovery_fee  42420 non-null  float64
#  42  last_pymnt_d             42420 non-null  object
#  43  last_pymnt_amnt          42420 non-null  float64
#  44  last_credit_pull_d       42420 non-null  object
#  45  last_fico_range_high     42420 non-null  float64
#  46  last_fico_range_low      42420 non-null  float64
#  47  policy_code              42420 non-null  float64
#  48  application_type         42420 non-null  object
#  49  acc_now_delinq           42420 non-null  float64
#  50  delinq_amnt              42420 non-null  float64
#  51  pub_rec_bankruptcies     42420 non-null  float64
# dtypes: float64(31), object(21)
# memory usage: 16.8+ MB

# %% [markdown]
# ### member_id

# %%
new_clean_df['member_id'] = new_clean_df['member_id'].astype('int')

# %%
new_clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599    5000.0     5000.0       4975.0            36 months
# 1  1077430  1314167    2500.0     2500.0       2500.0            60 months
# 2  1077175  1313524    2400.0     2400.0       2400.0            36 months
# 3  1076863  1277178    10000.0    10000.0      10000.0           36 months
# 4  1075358  1311748    3000.0     3000.0       3000.0            60 months
#
#   int_rate  installment grade sub_grade  ... last_pymnt_d last_pymnt_amnt  \
# 0   10.65%  162.87       B     B2        ...  Jan-2015     171.62
# 1   15.27%  59.83        C     C4        ...  Apr-2013     119.66
# 2   15.96%  84.33        C     C5        ...  Jun-2014     649.91
# 3   13.49%  339.31       C     C1        ...  Jan-2015     357.48
# 4   12.69%  67.79        B     B5        ...  Sep-2016     67.79
#
#   last_credit_pull_d  last_fico_range_high last_fico_range_low policy_code  \
# 0  Sep-2016           744.0                 740.0               1.0
# 1  Sep-2016           499.0                 0.0                 1.0
# 2  Sep-2016           719.0                 715.0               1.0
# 3  Apr-2016           604.0                 600.0               1.0
# 4  Sep-2016           694.0                 690.0               1.0
#
#   application_type acc_now_delinq delinq_amnt pub_rec_bankruptcies
# 0  INDIVIDUAL       0.0            0.0         0.0
# 1  INDIVIDUAL       0.0            0.0         0.0
# 2  INDIVIDUAL       0.0            0.0         0.0
# 3  INDIVIDUAL       0.0            0.0         0.0
# 4  INDIVIDUAL       0.0            0.0         0.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ### term

# %%
new_clean_df['term'].value_counts()
# Out:
#  36 months    31437
#  60 months    10983
# Name: term, dtype: int64

# %%
new_clean_df['term'].replace({' 36 months':36, ' 60 months':60}, inplace=True)

# %%
new_clean_df['term_months'] = new_clean_df['term'].copy()

# %%
new_clean_df.drop(columns=['term'], axis=1, inplace=True)

# %%
new_clean_df['term_months'].dtype
# Out:
# dtype('int64')

# %%
new_clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv int_rate  \
# 0  1077501  1296599    5000.0     5000.0       4975.0            10.65%
# 1  1077430  1314167    2500.0     2500.0       2500.0            15.27%
# 2  1077175  1313524    2400.0     2400.0       2400.0            15.96%
# 3  1076863  1277178    10000.0    10000.0      10000.0           13.49%
# 4  1075358  1311748    3000.0     3000.0       3000.0            12.69%
#
#    installment grade sub_grade                 emp_title  ... last_pymnt_amnt  \
# 0  162.87       B     B2        Other                     ...  171.62
# 1  59.83        C     C4        Ryder                     ...  119.66
# 2  84.33        C     C5        Other                     ...  649.91
# 3  339.31       C     C1        AIR RESOURCES BOARD       ...  357.48
# 4  67.79        B     B5        University Medical Group  ...  67.79
#
#   last_credit_pull_d  last_fico_range_high last_fico_range_low policy_code  \
# 0  Sep-2016           744.0                 740.0               1.0
# 1  Sep-2016           499.0                 0.0                 1.0
# 2  Sep-2016           719.0                 715.0               1.0
# 3  Apr-2016           604.0                 600.0               1.0
# 4  Sep-2016           694.0                 690.0               1.0
#
#   application_type acc_now_delinq delinq_amnt pub_rec_bankruptcies term_months
# 0  INDIVIDUAL       0.0            0.0         0.0                  36
# 1  INDIVIDUAL       0.0            0.0         0.0                  60
# 2  INDIVIDUAL       0.0            0.0         0.0                  36
# 3  INDIVIDUAL       0.0            0.0         0.0                  36
# 4  INDIVIDUAL       0.0            0.0         0.0                  60
#
# [5 rows x 52 columns]

# %% [markdown]
# ### int_rate

# %%
import re

# %%
def nums(x):
    num = re.compile(r'[\d.]+').findall(x)
    return num[0]

# %%
new_clean_df['int_rate_%'] = new_clean_df['int_rate'].apply(nums)

# %%
new_clean_df['int_rate_%'] = pd.to_numeric(new_clean_df['int_rate_%'])

# %%
new_clean_df['int_rate_%'].dtype
# Out:
# dtype('float64')

# %%
new_clean_df.drop(columns=['int_rate'], axis=1, inplace=True)

# %%
new_clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  \
# 0  1077501  1296599    5000.0     5000.0       4975.0           162.87
# 1  1077430  1314167    2500.0     2500.0       2500.0           59.83
# 2  1077175  1313524    2400.0     2400.0       2400.0           84.33
# 3  1076863  1277178    10000.0    10000.0      10000.0          339.31
# 4  1075358  1311748    3000.0     3000.0       3000.0           67.79
#
#   grade sub_grade                 emp_title emp_length  ...  \
# 0  B     B2        Other                     10+ years  ...
# 1  C     C4        Ryder                     < 1 year   ...
# 2  C     C5        Other                     10+ years  ...
# 3  C     C1        AIR RESOURCES BOARD       10+ years  ...
# 4  B     B5        University Medical Group  1 year     ...
#
#   last_credit_pull_d  last_fico_range_high last_fico_range_low policy_code  \
# 0  Sep-2016           744.0                 740.0               1.0
# 1  Sep-2016           499.0                 0.0                 1.0
# 2  Sep-2016           719.0                 715.0               1.0
# 3  Apr-2016           604.0                 600.0               1.0
# 4  Sep-2016           694.0                 690.0               1.0
#
#   application_type acc_now_delinq delinq_amnt pub_rec_bankruptcies  \
# 0  INDIVIDUAL       0.0            0.0         0.0
# 1  INDIVIDUAL       0.0            0.0         0.0
# 2  INDIVIDUAL       0.0            0.0         0.0
# 3  INDIVIDUAL       0.0            0.0         0.0
# 4  INDIVIDUAL       0.0            0.0         0.0
#
#   term_months int_rate_%
# 0  36          10.65
# 1  60          15.27
# 2  36          15.96
# 3  36          13.49
# 4  60          12.69
#
# [5 rows x 52 columns]

# %% [markdown]
# ### emp_length

# %%
new_clean_df['emp_length'].value_counts()
# Out:
# 10+ years    9356
# < 1 year     6139
# 2 years      4734
# 3 years      4355
# 4 years      3641
# 1 year       3578
# 5 years      3448
# 6 years      2371
# 7 years      1874
# 8 years      1588
# 9 years      1336
# Name: emp_length, dtype: int64

# %%
new_clean_df['emp_length_year'] = new_clean_df['emp_length'].replace({'< 1 year':'0'})

# %%
new_clean_df['emp_length_year'] = new_clean_df['emp_length_year'].apply(nums)

# %%
new_clean_df['emp_length_year'] = new_clean_df['emp_length_year'].astype('int64')

# %% [markdown]
# ### revol_util

# %%
new_clean_df['revol_util']
# Out:
# 0        83.7%
# 1        9.4%
# 2        98.5%
# 3        21%
# 4        53.9%
#          ...
# 42415    0%
# 42416    85%
# 42417    2.2%
# 42418    66%
# 42419    63.5%
# Name: revol_util, Length: 42420, dtype: object

# %%
new_clean_df['revol_util_%'] = new_clean_df['revol_util'].apply(nums)

# %%
new_clean_df['revol_util_%'] = new_clean_df['revol_util_%'].astype('float64')

# %%
new_clean_df.drop(columns=['emp_length','revol_util'], axis=1, inplace=True)

# %%
new_clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  \
# 0  1077501  1296599    5000.0     5000.0       4975.0           162.87
# 1  1077430  1314167    2500.0     2500.0       2500.0           59.83
# 2  1077175  1313524    2400.0     2400.0       2400.0           84.33
# 3  1076863  1277178    10000.0    10000.0      10000.0          339.31
# 4  1075358  1311748    3000.0     3000.0       3000.0           67.79
#
#   grade sub_grade                 emp_title home_ownership  ...  \
# 0  B     B2        Other                     RENT           ...
# 1  C     C4        Ryder                     RENT           ...
# 2  C     C5        Other                     RENT           ...
# 3  C     C1        AIR RESOURCES BOARD       RENT           ...
# 4  B     B5        University Medical Group  RENT           ...
#
#    last_fico_range_low policy_code application_type acc_now_delinq  \
# 0  740.0                1.0         INDIVIDUAL       0.0
# 1  0.0                  1.0         INDIVIDUAL       0.0
# 2  715.0                1.0         INDIVIDUAL       0.0
# 3  600.0                1.0         INDIVIDUAL       0.0
# 4  690.0                1.0         INDIVIDUAL       0.0
#
#   delinq_amnt pub_rec_bankruptcies term_months int_rate_% emp_length_year  \
# 0  0.0         0.0                  36          10.65      10
# 1  0.0         0.0                  60          15.27      0
# 2  0.0         0.0                  36          15.96      10
# 3  0.0         0.0                  36          13.49      10
# 4  0.0         0.0                  60          12.69      1
#
#    revol_util_%
# 0  83.7
# 1  9.4
# 2  98.5
# 3  21.0
# 4  53.9
#
# [5 rows x 52 columns]

# %% [markdown]
# ### total_pymnt

# %%
new_clean_df['total_pymnt']
# Out:
# 0        5863.155187
# 1        1008.710000
# 2        3005.666844
# 3        12231.890000
# 4        3784.490000
#             ...
# 42415    6486.773238
# 42416    12622.317947
# 42417    2227.023184
# 42418    7029.871272
# 42419    5084.724868
# Name: total_pymnt, Length: 42420, dtype: float64

# %%
new_clean_df['total_pymnt'] = new_clean_df['total_pymnt'].apply(lambda x:np.round(x, decimals=2))

# %%
new_clean_df['total_pymnt']
# Out:
# 0        5863.16
# 1        1008.71
# 2        3005.67
# 3        12231.89
# 4        3784.49
#           ...
# 42415    6486.77
# 42416    12622.32
# 42417    2227.02
# 42418    7029.87
# 42419    5084.72
# Name: total_pymnt, Length: 42420, dtype: float64

# %%
new_clean_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  \
# 0  1077501  1296599    5000.0     5000.0       4975.0           162.87
# 1  1077430  1314167    2500.0     2500.0       2500.0           59.83
# 2  1077175  1313524    2400.0     2400.0       2400.0           84.33
# 3  1076863  1277178    10000.0    10000.0      10000.0          339.31
# 4  1075358  1311748    3000.0     3000.0       3000.0           67.79
#
#   grade sub_grade                 emp_title home_ownership  ...  \
# 0  B     B2        Other                     RENT           ...
# 1  C     C4        Ryder                     RENT           ...
# 2  C     C5        Other                     RENT           ...
# 3  C     C1        AIR RESOURCES BOARD       RENT           ...
# 4  B     B5        University Medical Group  RENT           ...
#
#    last_fico_range_low policy_code application_type acc_now_delinq  \
# 0  740.0                1.0         INDIVIDUAL       0.0
# 1  0.0                  1.0         INDIVIDUAL       0.0
# 2  715.0                1.0         INDIVIDUAL       0.0
# 3  600.0                1.0         INDIVIDUAL       0.0
# 4  690.0                1.0         INDIVIDUAL       0.0
#
#   delinq_amnt pub_rec_bankruptcies term_months int_rate_% emp_length_year  \
# 0  0.0         0.0                  36          10.65      10
# 1  0.0         0.0                  60          15.27      0
# 2  0.0         0.0                  36          15.96      10
# 3  0.0         0.0                  36          13.49      10
# 4  0.0         0.0                  60          12.69      1
#
#    revol_util_%
# 0  83.7
# 1  9.4
# 2  98.5
# 3  21.0
# 4  53.9
#
# [5 rows x 52 columns]

# %%
new_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42420 entries, 0 to 42419
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       42420 non-null  object
#  1   member_id                42420 non-null  int32
#  2   loan_amnt                42420 non-null  float64
#  3   funded_amnt              42420 non-null  float64
#  4   funded_amnt_inv          42420 non-null  float64
#  5   installment              42420 non-null  float64
#  6   grade                    42420 non-null  object
#  7   sub_grade                42420 non-null  object
#  8   emp_title                42420 non-null  object
#  9   home_ownership           42420 non-null  object
#  10  annual_inc               42420 non-null  float64
#  11  verification_status      42420 non-null  object
#  12  issue_d                  42420 non-null  object
#  13  loan_status              42420 non-null  object
#  14  pymnt_plan               42420 non-null  object
#  15  purpose                  42420 non-null  object
#  16  title                    42420 non-null  object
#  17  zip_code                 42420 non-null  object
#  18  addr_state               42420 non-null  object
#  19  dti                      42420 non-null  float64
#  20  delinq_2yrs              42420 non-null  float64
#  21  fico_range_low           42420 non-null  float64
#  22  fico_range_high          42420 non-null  float64
#  23  inq_last_6mths           42420 non-null  float64
#  24  open_acc                 42420 non-null  float64
#  25  pub_rec                  42420 non-null  float64
#  26  revol_bal                42420 non-null  float64
#  27  total_acc                42420 non-null  float64
#  28  initial_list_status      42420 non-null  object
#  29  out_prncp                42420 non-null  float64
#  30  out_prncp_inv            42420 non-null  float64
#  31  total_pymnt              42420 non-null  float64
#  32  total_pymnt_inv          42420 non-null  float64
#  33  total_rec_prncp          42420 non-null  float64
#  34  total_rec_int            42420 non-null  float64
#  35  total_rec_late_fee       42420 non-null  float64
#  36  recoveries               42420 non-null  float64
#  37  collection_recovery_fee  42420 non-null  float64
#  38  last_pymnt_d             42420 non-null  object
#  39  last_pymnt_amnt          42420 non-null  float64
#  40  last_credit_pull_d       42420 non-null  object
#  41  last_fico_range_high     42420 non-null  float64
#  42  last_fico_range_low      42420 non-null  float64
#  43  policy_code              42420 non-null  float64
#  44  application_type         42420 non-null  object
#  45  acc_now_delinq           42420 non-null  float64
#  46  delinq_amnt              42420 non-null  float64
#  47  pub_rec_bankruptcies     42420 non-null  float64
#  48  term_months              42420 non-null  int64
#  49  int_rate_%               42420 non-null  float64
#  50  emp_length_year          42420 non-null  int64
#  51  revol_util_%             42420 non-null  float64
# dtypes: float64(32), int32(1), int64(2), object(17)
# memory usage: 16.7+ MB

# %%
new_clean_df.shape
# Out:
# (42420, 52)

# %%
cols = new_clean_df.columns.to_list()

# %%
new_clean_df[cols[:26]].describe()
# Out:
#           member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  4.242000e+04  42420.000000  42420.000000  42420.000000
# mean   8.262932e+05  11100.622348  10831.808699  10152.617744
# std    2.789670e+05  7409.234126   7144.781810   7129.781409
# min    7.069400e+04  500.000000    500.000000    0.000000
# 25%    6.391245e+05  5200.000000   5075.000000   4950.000000
# 50%    8.244245e+05  9775.000000   9600.000000   8500.000000
# 75%    1.034200e+06  15000.000000  15000.000000  14000.000000
# max    1.314167e+06  35000.000000  35000.000000  35000.000000
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  42420.000000  4.242000e+04  42420.000000  42420.000000  42420.000000
# mean   322.899562    6.916992e+04  13.380188     0.152263      713.073432
# std    208.855377    6.413422e+04  6.724445      0.511900      36.181801
# min    15.670000     1.896000e+03  0.000000      0.000000      610.000000
# 25%    165.740000    4.000000e+04  8.210000      0.000000      685.000000
# 50%    278.150000    5.900000e+04  13.480000     0.000000      710.000000
# 75%    428.592500    8.250000e+04  18.690000     0.000000      740.000000
# max    1305.190000   6.000000e+06  29.990000     13.000000     825.000000
#
#        fico_range_high  inq_last_6mths      open_acc       pub_rec
# count  42420.000000     42420.000000    42420.000000  42420.000000
# mean   717.073432       1.079939        9.348208      0.058086
# std    36.181801        1.526400        4.496276      0.245609
# min    614.000000       0.000000        1.000000      0.000000
# 25%    689.000000       0.000000        6.000000      0.000000
# 50%    714.000000       1.000000        9.000000      0.000000
# 75%    744.000000       2.000000        12.000000     0.000000
# max    829.000000       33.000000       47.000000     5.000000

# %%
new_clean_df[cols[26:]].describe()
# Out:
#           revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  \
# count  4.242000e+04  42420.000000  42420.000000  42420.000000   42420.000000
# mean   1.431655e+04  22.135785     11.881686     11.847924      12033.934292
# std    2.201725e+04  11.591170     125.544879    125.229754     9062.306765
# min    0.000000e+00  1.000000      0.000000      0.000000       33.730000
# 25%    3.650750e+03  13.000000     0.000000      0.000000       5485.712500
# 50%    8.840000e+03  20.000000     0.000000      0.000000       9708.325000
# 75%    1.726725e+04  29.000000     0.000000      0.000000       16435.160000
# max    1.207359e+06  90.000000     3555.850000   3553.300000    58563.680000
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# count  42420.000000     42420.000000     42420.000000   42420.000000
# mean   11327.443532     9687.817861      2245.268365    1.515029
# std    9005.108515      7081.864923      2584.846328    7.814771
# min    0.000000         0.000000         3.540000       0.000000
# 25%    4830.535000      4475.052500      662.262500     0.000000
# 50%    8979.345000      8000.000000      1343.810000    0.000000
# 75%    15548.560000     13500.000000     2808.922500    0.000000
# max    58563.680000     35000.020000     23823.750000   209.000000
#
#          recoveries  ...  last_fico_range_high  last_fico_range_low  \
# count  42420.000000  ...  42420.000000          42420.000000
# mean   99.333121     ...  689.584323            676.858911
# std    715.178966    ...  79.781562             118.034955
# min    0.000000      ...  0.000000              0.000000
# 25%    0.000000      ...  644.000000            640.000000
# 50%    0.000000      ...  699.000000            695.000000
# 75%    0.000000      ...  744.000000            740.000000
# max    29623.350000  ...  850.000000            845.000000
#
#        policy_code  acc_now_delinq   delinq_amnt  pub_rec_bankruptcies  \
# count  42420.0      42420.000000    42420.000000  42420.000000
# mean   1.0          0.000094        0.143329      0.043729
# std    0.0          0.009710        29.389325     0.205415
# min    1.0          0.000000        0.000000      0.000000
# 25%    1.0          0.000000        0.000000      0.000000
# 50%    1.0          0.000000        0.000000      0.000000
# 75%    1.0          0.000000        0.000000      0.000000
# max    1.0          1.000000        6053.000000   2.000000
#
#         term_months    int_rate_%  emp_length_year  revol_util_%
# count  42420.000000  42420.000000  42420.000000     42420.000000
# mean   42.213861     12.163146     4.798373         49.049401
# std    10.513002     3.708374      3.607687         28.400152
# min    36.000000     5.420000      0.000000         0.000000
# 25%    36.000000     9.630000      2.000000         25.600000
# 50%    36.000000     11.990000     4.000000         49.600000
# 75%    60.000000     14.720000     9.000000         72.600000
# max    60.000000     24.590000     10.000000        119.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Saving Data

# %%
new_clean_df.to_csv('dataset/new_lending_club_loans.csv', index=None)
