# %%
import numpy as np
import pandas as pd

# %%
desc_df = pd.read_csv('dataset/LCDataDictionary.csv')

# %%
desc_df
# Out:
#                LoanStatNew                                        Description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 112    verification_status  Indicates if income was verified by LC, not ve...
# 113  verified_status_joint  Indicates if the co-borrowers' joint income wa...
# 114               zip_code  The first 3 numbers of the zip code provided b...
# 115                    NaN                                                NaN
# 116                    NaN  * Employer Title replaces Employer Name for al...
#
# [117 rows x 2 columns]

# %%
loan_df = pd.read_csv('dataset/lending_club_loans.csv', skiprows=1, low_memory=False)

# %%
loan_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599.0     5000.0       5000.0           4975.0   36 months
# 1  1077430  1314167.0     2500.0       2500.0           2500.0   60 months
# 2  1077175  1313524.0     2400.0       2400.0           2400.0   36 months
# 3  1076863  1277178.0    10000.0      10000.0          10000.0   36 months
# 4  1075358  1311748.0     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
loan_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=115)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42538 entries, 0 to 42537
# Columns: 115 entries, id to total_il_high_credit_limit
# dtypes: float64(90), object(25)
# memory usage: 37.3+ MB

# %%
for cols in loan_df:
    print(cols,':',loan_df[cols].dtype)
# Out:
# id : object
# member_id : float64
# loan_amnt : float64
# funded_amnt : float64
# funded_amnt_inv : float64
# term : object
# int_rate : object
# installment : float64
# grade : object
# sub_grade : object
# emp_title : object
# emp_length : object
# home_ownership : object
# annual_inc : float64
# verification_status : object
# issue_d : object
# loan_status : object
# pymnt_plan : object
# url : object
# desc : object
# purpose : object
# title : object
# zip_code : object
# addr_state : object
# dti : float64
# delinq_2yrs : float64
# earliest_cr_line : object
# fico_range_low : float64
# fico_range_high : float64
# inq_last_6mths : float64
# mths_since_last_delinq : float64
# mths_since_last_record : float64
# open_acc : float64
# pub_rec : float64
# revol_bal : float64
# revol_util : object
# total_acc : float64
# initial_list_status : object
# out_prncp : float64
# out_prncp_inv : float64
# total_pymnt : float64
# total_pymnt_inv : float64
# total_rec_prncp : float64
# ...

# %%
for cols in loan_df:
    print(cols,':',loan_df[cols].notnull().sum(),'notnull')
# Out:
# id : 42538 notnull
# member_id : 42535 notnull
# loan_amnt : 42535 notnull
# funded_amnt : 42535 notnull
# funded_amnt_inv : 42535 notnull
# term : 42535 notnull
# int_rate : 42535 notnull
# installment : 42535 notnull
# grade : 42535 notnull
# sub_grade : 42535 notnull
# emp_title : 39909 notnull
# emp_length : 41423 notnull
# home_ownership : 42535 notnull
# annual_inc : 42531 notnull
# verification_status : 42535 notnull
# issue_d : 42535 notnull
# loan_status : 42535 notnull
# pymnt_plan : 42535 notnull
# url : 42535 notnull
# desc : 29242 notnull
# purpose : 42535 notnull
# title : 42522 notnull
# zip_code : 42535 notnull
# addr_state : 42535 notnull
# dti : 42535 notnull
# delinq_2yrs : 42506 notnull
# earliest_cr_line : 42506 notnull
# fico_range_low : 42535 notnull
# fico_range_high : 42535 notnull
# inq_last_6mths : 42506 notnull
# mths_since_last_delinq : 15609 notnull
# mths_since_last_record : 3651 notnull
# open_acc : 42506 notnull
# pub_rec : 42506 notnull
# ...

# %%
for cols in loan_df:
    print(cols,':',loan_df[cols].isnull().sum(),'null values')
# Out:
# id : 0 null values
# member_id : 3 null values
# loan_amnt : 3 null values
# funded_amnt : 3 null values
# funded_amnt_inv : 3 null values
# term : 3 null values
# int_rate : 3 null values
# installment : 3 null values
# grade : 3 null values
# sub_grade : 3 null values
# emp_title : 2629 null values
# emp_length : 1115 null values
# home_ownership : 3 null values
# annual_inc : 7 null values
# verification_status : 3 null values
# issue_d : 3 null values
# loan_status : 3 null values
# pymnt_plan : 3 null values
# url : 3 null values
# desc : 13296 null values
# purpose : 3 null values
# title : 16 null values
# zip_code : 3 null values
# addr_state : 3 null values
# dti : 3 null values
# delinq_2yrs : 32 null values
# earliest_cr_line : 32 null values
# fico_range_low : 3 null values
# fico_range_high : 3 null values
# inq_last_6mths : 32 null values
# mths_since_last_delinq : 26929 null values
# mths_since_last_record : 38887 null values
# open_acc : 32 null values
# ...

# %%
loan_df.shape
# Out:
# (42538, 115)

# %%
null_cols = []
for cols in loan_df:
    if loan_df[cols].isnull().sum() == loan_df.shape[0]:
        null_cols.append(cols)
        print(cols,':',loan_df[cols].isnull().sum(),'null values')
# Out:
# mths_since_last_major_derog : 42538 null values
# annual_inc_joint : 42538 null values
# dti_joint : 42538 null values
# verification_status_joint : 42538 null values
# tot_coll_amt : 42538 null values
# tot_cur_bal : 42538 null values
# open_acc_6m : 42538 null values
# open_il_6m : 42538 null values
# open_il_12m : 42538 null values
# open_il_24m : 42538 null values
# mths_since_rcnt_il : 42538 null values
# total_bal_il : 42538 null values
# il_util : 42538 null values
# open_rv_12m : 42538 null values
# open_rv_24m : 42538 null values
# max_bal_bc : 42538 null values
# all_util : 42538 null values
# total_rev_hi_lim : 42538 null values
# inq_fi : 42538 null values
# total_cu_tl : 42538 null values
# inq_last_12m : 42538 null values
# acc_open_past_24mths : 42538 null values
# avg_cur_bal : 42538 null values
# bc_open_to_buy : 42538 null values
# bc_util : 42538 null values
# mo_sin_old_il_acct : 42538 null values
# mo_sin_old_rev_tl_op : 42538 null values
# ...

# %%
len(null_cols)
# Out:
# 54

# %%
len(loan_df.columns)
# Out:
# 115
